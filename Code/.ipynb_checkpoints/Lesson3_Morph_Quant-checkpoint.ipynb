# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import skimage
import seaborn as sns
import os

# %%
data_path = '/Users/mhturner/Documents/GitHub/StanfordBIOS254-2019/Data/L2Data/'

# %%
from skimage.io import imread

data_fn = 'HAC-Cit-KRABdox_s41_t60.tif'
full_data_path = os.path.join(data_path, data_fn)
data = imread(full_data_path)

# %%
import json
metadata_fn = 'HAC-Cit-KRABdox_s41_t60.json'
with open(os.path.join(data_path, metadata_fn), mode='r') as metadata_ctl:
    meta_data = json.load(metadata_ctl)

# %%
slice = {}
for idx, channel in enumerate(meta_data['channels']):
    slice[channel] = data[:,:,idx]

# %%
brt_data = slice['DIC']
ch1_data = slice['YFP']
ch2_data = slice['RFP']

# %%
cha = ch1_data

# %%
def get_mask(im, threshold):
    mask = np.zeros(im.shape)
    mask[im >=threshold] = 1
    return(mask)

# %%
from skimage.filters.rank import minimum as min_filter
from skimage.filters.rank import median as median_filter
from skimage.morphology import disk

# %%
f_size = 4
cha_filtered = median_filter(cha, disk(f_size))

# %%
filter_radius = 12
cha_background = min_filter(cha_filtered, disk(filter_radius))

# %%
cha_bgs = cha_filtered - cha_background
cha_bgs[cha_bgs<0] = 0

# %%
from skimage.filters import threshold_otsu

thresh_otsu = threshold_otsu(cha_bgs)
mask_otsu = get_mask(cha_bgs, thresh_otsu)

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
ax[0].imshow(cha)
ax[0].set_title('Image')

ax[1].imshow(mask_otsu, cmap='gray')
ax[1].set_title('Otsu threshold')
# Out:
# Text(0.5, 1.0, 'Otsu threshold')

# %%
import skimage.morphology as sm
morph = sm.binary_erosion(mask_otsu,sm.disk(2))

# %%
from skimage.measure import label

cell_label_otsu = label(mask_otsu)
cell_num_otsu = np.amax(cell_label_otsu)

cell_label_morph=label(morph)
cell_num_morph = np.amax(cell_label_morph)

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 4))
ax[0].imshow(mask_otsu, cmap='gray')
ax[0].set_title('Before morphological operation')
ax[0].annotate(cell_num_otsu,xy=(175, 10), xycoords='figure pixels')

ax[1].imshow(morph, cmap='gray')
ax[1].set_title('After morphological operation')
ax[1].annotate(cell_num_morph,xy=(660, 10), xycoords='figure pixels')
# Out:
# Text(660, 10, '17')

# %% [markdown]
# ### 3.4 Quantifying Properties of Identified Regions or Cells

# %% [markdown]
# 3.4.1. Load lable function and label cells with different colors

# %% [markdown]
# 3.4.2. Load regionprops function and get the properties of the labeled cells

# %%
import matplotlib
cell_mask = morph
cell_labels = label(cell_mask)

cell_intensities = cha
cell_intensities[~cell_mask] = 0

# %% [markdown]
#  3.4.3. Load interactive function and show the chosen labeled cells

# %%
from skimage.measure import regionprops
from matplotlib import cm
props = regionprops(cell_labels, cell_intensities)

category_cmap = cm.get_cmap('Set1', len(props))

fig, ax = plt.subplots(1, figsize=(10,10))
plt.imshow(cell_labels,cmap = category_cmap)

# %%
cell_intensities.shape

# %%
cell_labels.shape

# %% [markdown]
# 3.4.4. Show single cell mask properties: 6th cell's area

# %%
props[2].area

# %% [markdown]
# #### Challenge: what is the actual value of area in mm^2? Note: using the scale in meta data.

# %% [markdown]
# 3.4.5. Show single cell mask properties: 6th cell's mean_intensity,centroid, weighted_centroid

# %%
props[5].mean_intensity

# %%
props[5].centroid

# %%
props[5].weighted_centroid

# %% [markdown]
# 3.4.6. Measures of roundness

# %% [markdown]
# Ratio

# %%
bounding_box = props[5].bbox
aspect_ratio = 1. * (bounding_box[3] - bounding_box[1]) / (bounding_box[2] - bounding_box[0])
print(aspect_ratio)

# %% [markdown]
# Solidity

# %%
props[5].solidity

# %% [markdown]
# Roundness
